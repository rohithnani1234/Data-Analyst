# %% [markdown]
# Cat plot,
# sns.catplot(x='',y='',data=df,kind=''),
# it is came from the factor plot which was deprecated,
# 9we use catplot insted of factorplot,
# kind is used to plot multiple plots in a single plot,

# %% [raw]
# categorical scatterplots with catplot
# stripplot()-with kind='strip'
# swarmplot()-with kind='swarm'

# %% [raw]
# categorical distribution plots with catplot
# boxplot()-with kind='box'
# violinplot()-with kind='violin'
# boxenplot()-with kind='boxen'

# %% [raw]
# categorical estimate plots with catplot
# pointplot()-with kind='point'
# barplot()-with kind='bar'
# countplot()-with kind='count'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
var=sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day',y='total_bill',data=var)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=var,hue='sex',kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=var,hue='sex',kind='strip')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=var,hue='sex',kind='swarm')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=var,hue='sex',kind='box')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=var,hue='sex',kind='violin')
plt.show()

# %%
sns.catplot(x='size',y='total_bill',data=var,hue='sex',kind='boxen')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=var,hue='sex',kind='point',height=3)
plt.show()

# %%
sns.catplot(x='day',y='size',data=var,hue='sex',paliette='Accent',kind='count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 sns.catplot(x='day',y='size',data=var,hue='sex',paliette='Accent',kind='count')
#       2 plt.show()
#
# File ~\anaconda\Lib\site-packages\seaborn\categorical.py:2780, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2778         y = 1
#    2779     elif x is not None and y is not None:
# -> 2780         raise ValueError("Cannot pass values for both `x` and `y`.")
#    2782 p = Plotter(
#    2783     data=data,
#    2784     variables=dict(
#    (...)
#    2792     legend=legend,
#    2793 )
#    2795 for var in ["row", "col"]:
# ...
